# %%
# !pip install "ultralytics<=8.3.40"

# %%
# !pip install roboflow

# %%
from ultralytics import YOLO

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="")
project = rf.workspace("kuivashev").project("hopefully-final-2zc5r")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml epochs=60 imgsz=640 batch=48

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/detect/train/weights/best.pt data={dataset.location}/data.yaml

# %%
# !cp -r /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/models/yolo/yolo_latest

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/detect/train4/weights/best.pt conf=0.25 source={dataset.location}/test/images
